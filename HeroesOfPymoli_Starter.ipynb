# %%
import pandas as pd

df = pd.read_csv('purchase_data.csv')
df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
totalplayers=df["SN"].nunique()
totalplayers
# Out:
# 576

# %%
numberofuniqueitems = df["Item ID"].nunique()
avgpurchaseprice = df["Price"].mean()
totalnumberofpurchases = df["Purchase ID"].count()
totalrevenue = df["Price"].sum()

                              
pa = ({"number of unique items":[numberofuniqueitems],
       "average purchase price":[avgpurchaseprice],
       "total number of purchases":[totalnumberofpurchases],
       "total revenue":[totalrevenue]})
    

Analysis_df = pd.DataFrame([numberofuniqueitems,avgpurchaseprice,totalnumberofpurchases,totalrevenue])
PurchaseAnalysis_df = Analysis_df.T
PurchaseAnalysis_df.columns = ["number of unique items","average purchase price","total number of purchases","total revenue"]
PurchaseAnalysis_df
# Out:
#    number of unique items  average purchase price  total number of purchases  \
# 0                   179.0                3.050987                      780.0
#
#    total revenue
# 0        2379.77

# %%
# maleplayers = df[df["Gender"] == "Male"]
# maleplayercount = maleplayers["SN"].nunique()
# femaleplayers = df[df["Gender"] == "Female"]
# femaleplayercount = femaleplayers["SN"].nunique()                    
# otherplayers = df[df["Gender"] == "Other / Nondisclosed"]
# otherplayercount = otherplayers["SN"].nunique()
                     
# gd = pd.DataFrame
                     
# "maleplayercount":[maleplayercount],
# "femaleplayercount":[femaleplayercount],
# "otherplayercount":[otherplayercount],

gendertotal = df.groupby("Gender")["SN"].nunique()
pct = (gendertotal / totalplayers) * 100

gd = pd.DataFrame({"Total Count": gendertotal, "Percent of Players": pct})
gd["Percent of Players"] = gd["Percent of Players"].map("{:.2f}%".format)
gd
# Out:
#                        Total Count Percent of Players
# Gender
# Female                          81             14.06%
# Male                           484             84.03%
# Other / Non-Disclosed           11              1.91%

# %%
output=df.groupby('Gender').agg({'Price':['count','mean','sum']})
## This calculates the avg total person
output.loc[:,('Price','Avg total per person')]=output.loc[:,('Price','sum')]/df.groupby("Gender")["SN"].nunique()
output
# Out:
#                       Price
#                       count      mean      sum Avg total per person
# Gender
# Female                  113  3.203009   361.94             4.468395
# Male                    652  3.017853  1967.64             4.065372
# Other / Non-Disclosed    15  3.346000    50.19             4.562727

# %%
## - {} --> dictionary {key:value , key:value}
## - [] --> List
## - () --> tupple

# %%
## Rename the column names
output=output.rename(columns={'Price':'Output','count':'Purchase Count','mean':'Average Purchase Price','sum':'Total Purchase value'})

# %%
output
# Out:
#                               Output                         \
#                       Purchase Count Average Purchase Price
# Gender
# Female                           113               3.203009
# Male                             652               3.017853
# Other / Non-Disclosed             15               3.346000
#
#
#                       Total Purchase value Avg total per person
# Gender
# Female                              361.94             4.468395
# Male                               1967.64             4.065372
# Other / Non-Disclosed                50.19             4.562727

# %%
## Transform to two decimals and add dollar symbol ($)
import numpy as np
output.loc[:,('Output','Average Purchase Price')]=output.loc[:,('Output','Average Purchase Price')].apply(lambda x: '$'+str(np.round(x,2)))
output.loc[:,('Output','Total Purchase value')]=output.loc[:,('Output','Total Purchase value')].apply(lambda x: '$'+str(np.round(x,2)))
output.loc[:,('Output','Avg total per person')]=output.loc[:,('Output','Avg total per person')].apply(lambda x: '$'+str(np.round(x,2)))

# %%
## apply is a method used on Series, we apply one function to all the entries of the Series

# %%
output
# Out:
#                               Output                         \
#                       Purchase Count Average Purchase Price
# Gender
# Female                           113                   $3.2
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#
#                       Total Purchase value Avg total per person
# Gender
# Female                             $361.94                $4.47
# Male                              $1967.64                $4.07
# Other / Non-Disclosed               $50.19                $4.56

# %% [markdown]
# ## Age Demographics

# %%
#age_demographics = df.groupby(bins)[['SN']].agg('nunique').rename(columns={'SN':'Total Count'})

# %%
bins=pd.cut(df['Age'],[0,9,14,19,24,29,34,39,100])
output1=df.groupby(bins)[['SN']].agg('nunique').rename(columns={'SN':'Total Count'})
output1['Percentage of Players']=(output1['Total Count']/576*100).apply(lambda x: str(np.round(x,2))+'%')
output1.index=['<10','10-14','15-19','20-24','25-29','30-34','35-39','40+']
#output1['Percentage of Players']=output1['Percentage of Players']

# %%
output1
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %%
output1.columns
# Out:
# Index(['Total Count', 'Percentage of Players'], dtype='object')

# %%
output1.index
# Out:
# Index(['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+'], dtype='object')

# %% [markdown]
# ## Purchasing Analysis (Age)

# %%
output2=df.groupby(bins).agg({'Price':['count','mean','sum']})
output2
# Out:
#           Price
#           count      mean      sum
# Age
# (0, 9]       23  3.353478    77.13
# (9, 14]      28  2.956429    82.78
# (14, 19]    136  3.035956   412.89
# (19, 24]    365  3.052219  1114.06
# (24, 29]    101  2.900990   293.00
# (29, 34]     73  2.931507   214.00
# (34, 39]     41  3.601707   147.67
# (39, 100]    13  2.941538    38.24

# %%
## Calculate Average total per person on each range: Total Purchase value / number of unique people per range
output2.loc[:,('Price','Avg total per person')]=output2.loc[:,('Price','sum')]/df.groupby(bins)["SN"].nunique()

# %%
## Rename column names
output2.rename(columns={'Price':'Output','count':'Purchase Count','mean':'Average Purchase Price','sum':'Total Purchase value'},inplace=True)

## Change values to two decimals and add dollar symbol ($)
output2.loc[:,('Output','Average Purchase Price')]=output2.loc[:,('Output','Average Purchase Price')].apply(lambda x: '$'+str(np.round(x,2)))
output2.loc[:,('Output','Total Purchase value')]=output2.loc[:,('Output','Total Purchase value')].apply(lambda x: '$'+str(np.round(x,2)))
output2.loc[:,('Output','Avg total per person')]=output2.loc[:,('Output','Avg total per person')].apply(lambda x: '$'+str(np.round(x,2)))

# %%
## Rename the index values
output2.index=['<10','10-14','15-19','20-24','25-29','30-34','35-39','40+']

# %%
output2
# Out:
#               Output                                              \
#       Purchase Count Average Purchase Price Total Purchase value
# <10               23                  $3.35               $77.13
# 10-14             28                  $2.96               $82.78
# 15-19            136                  $3.04              $412.89
# 20-24            365                  $3.05             $1114.06
# 25-29            101                   $2.9               $293.0
# 30-34             73                  $2.93               $214.0
# 35-39             41                   $3.6              $147.67
# 40+               13                  $2.94               $38.24
#
#
#       Avg total per person
# <10                  $4.54
# 10-14                $3.76
# 15-19                $3.86
# 20-24                $4.32
# 25-29                $3.81
# 30-34                $4.12
# 35-39                $4.76
# 40+                  $3.19

# %%
## Total number of unique people per age range
#df.groupby(bins)["SN"].nunique()

# %% [markdown]
# ## Top Spenders

# %%
aux=df.groupby(by='SN').agg({'Price':['count','mean','sum']})

# %%
df.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %%
aux.columns
# Out:
# MultiIndex([('Price', 'count'),
#             ('Price',  'mean'),
#             ('Price',   'sum')],
#            )

# %%
output3=df.groupby(by='SN').agg({'Price':['count','mean','sum']}).sort_values(by=('Price','sum'),ascending=False).head()
output3.rename(columns={'Price':'Output','count':'Purchase Count','mean':'Average Purchase Price','sum':'Total Purchase value'})
output3
# Out:
#             Price
#             count      mean    sum
# SN
# Lisosia93       5  3.792000  18.96
# Idastidru52     4  3.862500  15.45
# Chamjask73      3  4.610000  13.83
# Iral74          4  3.405000  13.62
# Iskadarya95     3  4.366667  13.10

# %%
## When inplace=False
output3.rename(columns={'Price':'Output','count':'Purchase Count','mean':'Average Purchase Price','sum':'Total Purchase value'})
# Out:
#                     Output
#             Purchase Count Average Purchase Price Total Purchase value
# SN
# Lisosia93                5                  $3.79               $18.96
# Idastidru52              4                  $3.86               $15.45
# Chamjask73               3                  $4.61               $13.83
# Iral74                   4                   $3.4               $13.62
# Iskadarya95              3                  $4.37                $13.1

# %%
output3
# Out:
#             Price
#             count      mean    sum
# SN
# Lisosia93       5  3.792000  18.96
# Idastidru52     4  3.862500  15.45
# Chamjask73      3  4.610000  13.83
# Iral74          4  3.405000  13.62
# Iskadarya95     3  4.366667  13.10

# %%
#output3.rename(columns={'Price':'Output','count':'Purchase Count','mean':'Average Purchase Price','sum':'Total Purchase value'},inplace=True)

# %%
## Same effect as inplace=True
# output3=output3.rename(columns={'Price':'Output','count':'Purchase Count','mean':'Average Purchase Price','sum':'Total Purchase value'})

# %%
## Rename column names
#output3.rename(columns={'Price':'Output','count':'Purchase Count','mean':'Average Purchase Price','sum':'Total Purchase value'},inplace=True)
output3=output3.rename(columns={'Price':'Output','count':'Purchase Count','mean':'Average Purchase Price','sum':'Total Purchase value'})

## Change values to two decimals and add dollar symbol ($)
output3.loc[:,('Output','Average Purchase Price')]=output3.loc[:,('Output','Average Purchase Price')].apply(lambda x: '$'+str(np.round(x,2)))
output3.loc[:,('Output','Total Purchase value')]=output3.loc[:,('Output','Total Purchase value')].apply(lambda x: '$'+str(np.round(x,2)))

# %%
output3
# Out:
#                     Output
#             Purchase Count Average Purchase Price Total Purchase value
# SN
# Lisosia93                5                  $3.79               $18.96
# Idastidru52              4                  $3.86               $15.45
# Chamjask73               3                  $4.61               $13.83
# Iral74                   4                   $3.4               $13.62
# Iskadarya95              3                  $4.37                $13.1

# %%
## loc allows you to acces specific information of your dataframe: specifc rows, specific columns

# %%
## ## iloc is another method to access information of dataframe based on the index

# %% [markdown]
# ## Most Popular Items

# %%
## Count the number of times each item was bought (Item Name or Item ID)
## groupby. ----> count

# %%
df.groupby(by='Item Name').agg({'Price':['count','mean','sum']}).sort_values(by=('Price','count'),ascending=False).head()
# Out:
#                                              Price
#                                              count      mean    sum
# Item Name
# Final Critic                                    13  4.614615  59.99
# Oathbreaker, Last Hope of the Breaking Storm    12  4.230000  50.76
# Persuasion                                       9  3.221111  28.99
# Nirvana                                          9  4.900000  44.10
# Extraction, Quickblade Of Trembling Hands        9  3.530000  31.77

# %% [markdown]
# ## Most Profitable Items

# %%
output4=df.groupby(by='Item Name').agg({'Price':['count','mean','sum']}).sort_values(by=('Price','sum'),ascending=False).head()

# %%
output4
# Out:
#                                              Price
#                                              count      mean    sum
# Item Name
# Final Critic                                    13  4.614615  59.99
# Oathbreaker, Last Hope of the Breaking Storm    12  4.230000  50.76
# Nirvana                                          9  4.900000  44.10
# Fiery Glass Crusader                             9  4.580000  41.22
# Singed Scalpel                                   8  4.350000  34.80
